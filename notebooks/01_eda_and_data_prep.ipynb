# %% [markdown]
# # 01. Exploratory Data Analysis & Data Preparation
# Dataset: `@SpotifyCares` Customer Support Q&A Pairs.

# %%
import os
import pandas as pd
from src.data_prep import generate_spotify_dataset, clean_text

# %%
# Generate and load cleaned Spotify pairs dataset
df_cleaned = generate_spotify_dataset()
df_cleaned.head(10)

# %%
# Display dataset stats and intent distribution
print('Total Pairs:', len(df_cleaned))
df_cleaned['intent_category'].value_counts()
