# %% [markdown]
# # 03. Historical Case Retrieval & Escalation Engine
# Demonstrating FAISS local vector retrieval and deterministic rule escalation.

# %%
from src.case_retrieval import CaseRetrievalEngine
from src.escalation_engine import EscalationEngine
from src.pipeline import SupportAssistantPipeline

# %%
# Test retrieval engine
retriever = CaseRetrievalEngine()
cases = retriever.retrieve_top_k('My Spotify desktop app crashed when I opened my playlists', k=3)
for c in cases: print(c)

# %%
# Test end-to-end pipeline
pipeline = SupportAssistantPipeline()
res = pipeline.process_message('You charged me twice $16.99 this month! Refund me!')
print(res)
