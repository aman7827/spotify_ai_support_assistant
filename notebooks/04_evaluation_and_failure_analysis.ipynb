# %% [markdown]
# # 04. Evaluation Results & Real Failure Analysis
# Analyzing 40-sample reply quality scores (LLM-as-a-Judge vs Human) and 5 concrete failure cases.

# %%
import pandas as pd
from evaluation.evaluate_replies import evaluate_replies
from evaluation.failure_analysis import generate_failure_analysis

# %%
# Run Reply Quality Evaluation
df_reply_summary = evaluate_replies()
df_reply_summary

# %%
# Run Failure Analysis
df_failures = generate_failure_analysis()
df_failures[['failure_id', 'customer_message', 'expected_intent', 'actual_intent', 'root_cause']]
