# %% [markdown]
# # 02. Intent Classification Benchmarks
# Comparing Baseline 1 (Majority), Baseline 2 (TF-IDF+LogReg), and Final Model (Sentence Transformer+LogReg).

# %%
import os
import pandas as pd
from evaluation.evaluate_intents import evaluate_models

# %%
# Execute model evaluation harness
df_metrics = evaluate_models()
df_metrics
